# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/saxue/Desktop/HW/pr/attacks.csv",encoding = 'ISO-8859-1')
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
df = pd.read_csv("D:/590-PR/final project/shark_attacks/attacks.csv",encoding = 'ISO-8859-1')
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
df = df[['Case Number', 'Date','Country', 'Area', 'Location','Activity','Sex ', 'Age', 'Injury', 'Fatal (Y/N)','Species ']]
df.rename(columns={'Case Number':'CaseNumber'}, inplace=True)
df.head()
# Out:
#    CaseNumber         Date    Country             Area  \
# 0  2018.06.25  25-Jun-2018        USA       California
# 1  2018.06.18  18-Jun-2018        USA          Georgia
# 2  2018.06.09  09-Jun-2018        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018     MEXICO           Colima
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#           Species
# 0      White shark
# 1              NaN
# 2              NaN
# 3        2 m shark
# 4  Tiger shark, 3m

# %%
df['Date'].isna().value_counts()
# Out:
# True     19421
# False     6302
# Name: Date, dtype: int64

# %%
df['Date'] = df['Date'].fillna('***')
na_date_index = df[df.Date == '***'].index.tolist()
#df.iloc[na_date_index]
df = df.drop(na_date_index)

# %%
df.CaseNumber.head(22)
# Out:
# 0       2018.06.25
# 1       2018.06.18
# 2       2018.06.09
# 3       2018.06.08
# 4       2018.06.04
# 5     2018.06.03.b
# 6     2018.06.03.a
# 7       2018.05.27
# 8     2018.05.26.b
# 9     2018.05.26.a
# 10      2018.05.24
# 11      2018.05.21
# 12    2018.05.13.b
# 13    2018.05.13.a
# 14      2018.05.00
# 15      2018.05.12
# 16      2018.05.09
# 17    2018.04.30.R
# 18    2018.04.28.b
# 19    2018.04.28.a
# 20    2018.04.25.b
# 21    2018.04.25.a
# Name: CaseNumber, dtype: object

# %%
from datetime import datetime
def date_prettify(date):
    #print(date)
    date = str(date)
    if (len(date) == 10 and date[5:7]!='00' and date[8:10]!='00' and int(date[5:7])<=31 and int(date[5:7])>0 and int(date[8:10])<=31 and int(date[8:10])>0):
        if date[4] == '.' and date[7] == '.':
            return str(datetime.strptime(date,'%Y.%m.%d'))[0:10]
        elif date[4] == '-' and date[7] == '-':
            return str(datetime.strptime(date,'%Y-%m-%d'))[0:10]
        elif date[4] == '.' and date[7] == '-':
            return str(datetime.strptime(date,'%Y.%m-%d'))[0:10]
        elif date[4] == '-' and date[7] == '.':
            return str(datetime.strptime(date,'%Y-%m.%d'))[0:10]
    elif (len(date) == 12 and date[5:7]!='00' and date[8:10]!='00' and int(date[5:7])<=31 and int(date[5:7])>0 and int (date[8:10])<=31 and int(date[8:10])>0):
        date = date[0:10]
        if date[4] == '.' and date[7] == '.':
            return str(datetime.strptime(date,'%Y.%m.%d'))[0:10]
        elif date[4] == '-' and date[7] == '-':
            return str(datetime.strptime(date,'%Y-%m-%d'))[0:10]
        elif date[4] == '.' and date[7] == '-':
            return str(datetime.strptime(date,'%Y.%m-%d'))[0:10]
        elif date[4] == '-' and date[7] == '.':
            return str(datetime.strptime(date,'%Y-%m.%d'))[0:10]
    else:
        return np.nan

# %%
df['CaseNumber'] = df['CaseNumber'].apply(date_prettify)
df['CaseNumber'] = df['CaseNumber'].fillna('***')
na_CaseNumber_index = df[df.CaseNumber == '***'].index.tolist()
na_CaseNumber_index
df = df.drop(na_CaseNumber_index)
df.head()
# Out:
#    CaseNumber         Date    Country             Area  \
# 0  2018-06-25  25-Jun-2018        USA       California
# 1  2018-06-18  18-Jun-2018        USA          Georgia
# 2  2018-06-09  09-Jun-2018        USA           Hawaii
# 3  2018-06-08  08-Jun-2018  AUSTRALIA  New South Wales
# 4  2018-06-04  04-Jun-2018     MEXICO           Colima
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#           Species
# 0      White shark
# 1              NaN
# 2              NaN
# 3        2 m shark
# 4  Tiger shark, 3m

# %%
df['Area'] = df['Area'].fillna('***')
na_Area_index = df[df.Area == '***'].index.tolist()
df = df.drop(na_Area_index)
#df.head(-10)

# %%
',' in 'Oceanside, San Diego County'
'Oceanside, San Diego County'.split(',')[-1].strip()[:-7]
# Out:
# 'San Diego'

# %%
def location_prettify(location):
    temp_loc = str(location)
    if ',' in temp_loc:
        temp_loc = temp_loc.split(',')[-1].strip()
        if 'County' in temp_loc:
            temp_loc = temp_loc[:-7]
        return temp_loc.strip()
    elif ',' not in temp_loc:
        return temp_loc

# %%
df['Location'] = df['Location'].apply(location_prettify)
#df[df['Country'] == 'USA'][['Location','Area']]
#df[df['Country'] == 'USA']['Location'].values
df.head()
# Out:
#    CaseNumber         Date    Country             Area            Location  \
# 0  2018-06-25  25-Jun-2018        USA       California           San Diego
# 1  2018-06-18  18-Jun-2018        USA          Georgia               Glynn
# 2  2018-06-09  09-Jun-2018        USA           Hawaii                Oahu
# 3  2018-06-08  08-Jun-2018  AUSTRALIA  New South Wales  Arrawarra Headland
# 4  2018-06-04  04-Jun-2018     MEXICO           Colima            La Ticla
#
#       Activity Sex   Age                                             Injury  \
# 0     Paddling    F   57  No injury to occupant, outrigger canoe and pad...
# 1     Standing    F   11                         Minor injury to left thigh
# 2      Surfing    M   48       Injury to left lower leg from surfboard skeg
# 3      Surfing    M  NaN                          Minor injury to lower leg
# 4  Free diving    M  NaN  Lacerations to leg & hand shark PROVOKED INCIDENT
#
#   Fatal (Y/N)         Species
# 0           N      White shark
# 1           N              NaN
# 2           N              NaN
# 3           N        2 m shark
# 4           N  Tiger shark, 3m

# %%
df_USA = df[df['Country'] == 'USA'][['CaseNumber','Country','Area','Location','Fatal (Y/N)']]
df_USA.reset_index(drop=True, inplace=True)
df_USA.head()
# Out:
#    CaseNumber Country        Area   Location Fatal (Y/N)
# 0  2018-06-25     USA  California  San Diego           N
# 1  2018-06-18     USA     Georgia      Glynn           N
# 2  2018-06-09     USA      Hawaii       Oahu           N
# 3  2018-05-27     USA     Florida    Volusia           N
# 4  2018-05-26     USA     Florida    Brevard           N

# %%
key = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho',
       'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi',
       'Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota',
       'Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont',
       'Virginia','Washington','West Virginia','Wisconsin','Wyoming']
value = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS',
         'MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV',
         'WI','WY']
dict_Area = dict(zip(key, value))
#dict_Area

# %%
'California'.strip() in dict_Area
#dict_Area['California']
# Out:
# True

# %%
def area_prettify(area):
    key = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho',
           'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi',
           'Missouri','Montana','Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York','North Carolina','North Dakota',
           'Ohio','Oklahoma','Oregon','Pennsylvania','Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah','Vermont',
           'Virginia','Washington','West Virginia','Wisconsin','Wyoming']
    value = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS',
             'MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV',
             'WI','WY']
    dict_Area = dict(zip(key, value))
    temp_area = str(area).strip()
    if temp_area in dict_Area:
        temp_area = dict_Area[temp_area]
        return temp_area
    elif temp_area not in dict_Area:
        return "NaN"

# %%
df_USA['Area'] = df_USA['Area'].apply(area_prettify)
df_USA.head()
# Out:
#    CaseNumber Country Area   Location Fatal (Y/N)
# 0  2018-06-25     USA   CA  San Diego           N
# 1  2018-06-18     USA   GA      Glynn           N
# 2  2018-06-09     USA   HI       Oahu           N
# 3  2018-05-27     USA   FL    Volusia           N
# 4  2018-05-26     USA   FL    Brevard           N

# %%
list_date = list(df_USA.CaseNumber)
list_state = list(df_USA.Area)
list_city = list(df_USA.Location)

# %%
print(len(list_date))
print(len(list_state))
print(len(list_city))
# Out:
# 2040
# 2040
# 2040

# %%
[时间,Location,Area]
3个list

# %%
import requests
import lxml.html
import re
from time import sleep
from requests.exceptions import ConnectionError

# %%
def get_temperature(state,city,date):
    temperature=[]
    for i,j,n in zip(state,city,date):
        url_1="https://www.almanac.com/weather/history/"
        url=url_1+i+'/'+j+'/'+n
        tree=None
        while tree is None:
            try:
                r=requests.get(url)
                print(r.status_code)
                if(r.status_code==200):
                    tree=lxml.html.fromstring(r.content)
                    content=tree.xpath('//tr[@class="weatherhistory_results_datavalue temp"]/td/p/span[@class="value"]/text()')
                    #content=content[0] 
                    temperature.append(content)
                    sleep(5)
                    break             
                elif(r.status_code==429):
                    tree=None
                    sleep(5)
                else:
                    content=['NaN']
                    temperature.append(content)
                    break
            except(ConnectionError, ConnectionRefusedError) as e:
                print('Error retrieving web page.  Retrying in 10 seconds...')
                sleep(10)
        
        print(i,j,content) 
    return temperature

# %%
temp=get_temperature(list_state,list_city,list_date)
# Out:
# 200
# CA San Diego ['66.6']
# 410
# GA Glynn ['NaN']
# 410
# HI Oahu ['NaN']
# 200
# FL Volusia ['75.2']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['77.4']
# 200
# SC Charleston ['75.7']
# 200
# SC Beaufort ['76.9']
# 410
# HI Kauai ['NaN']
# 410
# HI Kukio Beach ['NaN']
# 410
# HI Oahu ['NaN']
# 410
# CA Marin ['NaN']
# 200
# CA Monterey ['63.1']
# 410
# FL Brevard ['NaN']
# 410
# HI Oahu ['NaN']
# 200
# FL Palm Beach ['82.3']
# 200
# FL Palm Beach ['82.3']
# 200
# FL Palm Beach ['79.6']
# 410
# HI Kauai ['NaN']
# 410
# HI Maui ['NaN']
# 200
# FL Duval ['77.9']
# 410
# NY Rockaway ['NaN']
# 410
# FL Fort Worth ['NaN']
# 410
# FL Palm Beach County ['NaN']
# 200
# FL Volusia ['82.1']
# 200
# FL Volusia ['81.6']
# 410
# FL Monroe ['NaN']
# 200
# TX Cameron ['80.4']
# 200
# FL Volusia ['77.9']
# 410
# FL Bathtub Beach  ['NaN']
# 200
# MA Barnstable ['76.2']
# 200
# SC Beaufort ['76.9']
# 200
# MA Barnstable ['72.6']
# 200
# CA San Mateo ['61.3']
# 200
# FL Duval ['78.9']
# 200
# SC Beaufort ['81.1']
# 200
# SC Georgetown []
# 410
# NJ Ventnor ['NaN']
# 410
# FL Monroe ['NaN']
# 200
# SC Beaufort ['80.3']
# 200
# CA Santa Barbara ['63.9']
# 200
# CA Santa Barbara ['63.9']
# 410
# WA Grays Harbor ['NaN']
# 200
# CA Santa Cruz ['54.4']
# 410
# FL Miami-Dade ['NaN']
# 410
# SC Wrightsville Beach ['NaN']
# 200
# SC Beaufort ['78.2']
# 200
# FL Palm Beach ['82.6']
# 200
# SC Beaufort ['81.0']
# 200
# FL Volusia ['76.8']
# 410
# FL Monroe ['NaN']
# 200
# SC Charleston ['83.1']
# 410
# FL Off Jupiter ['NaN']
# 200
# CA Orange ['67.5']
# 200
# CA San Diego ['65.8']
# 200
# SC Charleston ['77.0']
# 410
# FL nan ['NaN']
# 410
# SC Georgetown County ['NaN']
# 200
# FL Volusia ['68.8']
# 410
# HI Kauai ['NaN']
# 200
# FL Duval ['66.6']
# 200
# FL St. Augustine ['70.5']
# 200
# FL Volusia ['66.9']
# 410
# FL Brevard ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['76.1']
# 200
# FL Volusia ['76.2']
# 410
# FL Okaloosa ['NaN']
# 200
# FL Volusia ['68.4']
# 410
# CA Monterey Bay ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# SC 16 miles off Hilton Head ['NaN']
# 410
# FL Indian River ['NaN']
# 200
# FL Jensen Beach ['75.4']
# 410
# FL Brevard ['NaN']
# 410
# FL St Lucie ['NaN']
# 200
# FL Volusia ['59.2']
# 410
# HI Maui ['NaN']
# 200
# FL Duval ['70.9']
# 410
# FL Mayport Naval Station  Duval County ['NaN']
# 410
# HI Maui ['NaN']
# 410
# HI Maui ['NaN']
# 410
# OR Clatsop ['NaN']
# 200
# FL Volusia ['76.3']
# 200
# FL Volusia ['76.8']
# 200
# FL Volusia ['80.9']
# 200
# FL Volusia ['80.9']
# 200
# FL Volusia ['80.9']
# 410
# CA Humboldt ['NaN']
# 200
# FL St. Johns ['85.4']
# 410
# HI Oahu ['NaN']
# 200
# SC Horry ['68.5']
# 200
# FL Volusia ['78.0']
# 200
# CA Santa Barbara ['65.0']
# 200
# FL Volusia ['80.7']
# 200
# FL Volusia ['80.7']
# 200
# FL St. Johns ['85.9']
# 410
# HI Maui ['NaN']
# 200
# FL Volusia ['80.5']
# 410
# FL Monroe ['NaN']
# 410
# AL 8 miles off Mobile ['NaN']
# 200
# FL Volusia ['85.4']
# 200
# FL Volusia ['85.4']
# 200
# CA Orange ['70.3']
# 200
# SC Horry ['79.5']
# 200
# CA Santa Cruz ['56.3']
# 410
# MA Essec ['NaN']
# 200
# CA Los Angeles ['69.7']
# 410
# FL Brevard ['NaN']
# 410
# SC Sullivan's Island ['NaN']
# 410
# NC Carteret ['NaN']
# 200
# SC Horry ['74.3']
# 410
# FL Brevard ['NaN']
# 410
# HI Kauai ['NaN']
# 200
# TX Galveston ['84.8']
# 410
# NC Carteret ['NaN']
# 200
# SC Charleston ['79.1']
# 410
# FL Flagler ['NaN']
# 200
# CA Orange ['63.7']
# 200
# FL Duval ['75.8']
# 410
# FL Indian River ['NaN']
# 410
# FL Pinellas ['NaN']
# 200
# FL Duval ['75.8']
# 200
# FL St. Johns ['76.9']
# 200
# FL Palm Beach ['80.9']
# 410
# HI Maui ['NaN']
# 200
# FL Volusia ['71.1']
# 200
# FL Palm Beach ['75.3']
# 410
# FL Monroe ['NaN']
# 200
# FL Palm Beach ['76.0']
# 410
# HI Maui ['NaN']
# 200
# FL Lee ['68.5']
# 200
# CA Orange ['57.4']
# 200
# FL St. Lucie ['72.8']
# 200
# FL Palm Beach ['73.4']
# 410
# HI Kauai ['NaN']
# 410
# HI  ['NaN']
# 410
# TX Off Surfside ['NaN']
# 410
# HI Maui ['NaN']
# 410
# HI La'aloa Beach Park ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Palm Beach ['77.4']
# 200
# FL Palm Beach ['77.4']
# 410
# FL Brevard ['NaN']
# 410
# HI Hawaii ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# HI Oahu ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# FL Broward ['NaN']
# 410
# HI  ['NaN']
# 410
# HI Oahu ['NaN']
# 200
# CA San Luis Obispo ['73.5']
# 200
# SC Beaufort ['72.8']
# 410
# HI Oahu ['NaN']
# 200
# FL St. Lucie ['72.0']
# 200
# TX Galveston ['70.8']
# 200
# FL Volusia ['69.5']
# 410
# FL St.  Johns ['NaN']
# 200
# CA Santa Barbara ['71.2']
# 200
# FL Volusia ['80.2']
# 410
# HI Big Island ['NaN']
# 410
# FL Nassau ['NaN']
# 410
# FL St.  Johns ['NaN']
# 200
# CA Santa Barbara ['72.1']
# 200
# FL Duval ['75.0']
# 200
# FL Duval ['73.5']
# 200
# CA Los Angeles ['74.0']
# 200
# CA Ventura ['68.2']
# 200
# SC Horry ['81.0']
# 200
# CA San Luis Obispo ['78.3']
# 200
# CA San Luis Obispo ['78.3']
# 410
# FL Brevard ['NaN']
# 200
# SC Georgetown []
# 200
# FL Duval ['78.4']
# 410
# CA Santa Barbara County ['NaN']
# 410
# CA Cortes Bank ['NaN']
# 200
# FL Volusia ['80.7']
# 200
# SC Colleton ['80.6']
# 200
# CA San Diego ['74.5']
# 200
# CA Orange ['69.0']
# 200
# CA Orange ['68.4']
# 200
# NC Pender ['76.0']
# 410
# NC Hyde ['NaN']
# 200
# SC Charleston ['81.0']
# 410
# NC Dare ['NaN']
# 200
# FL Duval ['78.9']
# 200
# SC Beaufort ['82.8']
# 410
# NC Dare ['NaN']
# 200
# NC Surf City ['84.5']
# 200
# SC Beaufort ['79.6']
# 200
# FL Daytona Beach Shores ['85.0']
# 200
# NC Brunswick ['85.5']
# 200
# NC Brunswick ['85.5']
# 410
# CA Off San Diego ['NaN']
# 200
# NC Brunswick ['79.8']
# 410
# FL Brevard ['NaN']
# 200
# FL Fort Lauderdale ['81.1']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['77.1']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['80.9']
# 410
# SC Sullivan's Island ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# HI Kanahena Cove  ['NaN']
# 200
# FL Marco Island ['82.1']
# 410
# FL Monroe ['NaN']
# 200
# FL Palm Beach ['76.4']
# 410
# HI Hapuna Beach ['NaN']
# 429
# 200
# HI Lahaina ['72.3']
# 410
# FL Off Panama City ['NaN']
# 429
# 410
# FL nan ['NaN']
# 429
# 410
# FL Indian River ['NaN']
# 429
# 200
# CA San Luis Obispo ['53.3']
# 200
# CA San Mateo ['59.3']
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI West Maui ['NaN']
# 429
# 200
# FL St. Lucie ['67.3']
# 410
# HI Hawaii ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# CA Santa Barbara ['65.6']
# 410
# HI South Maui ['NaN']
# 429
# 200
# SC Beaufort ['78.5']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['68.7']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['68.7']
# 410
# CA Santa Barbara County ['NaN']
# 429
# 410
# CA Santa Barbara County ['NaN']
# 429
# 200
# CA Santa Barbara ['70.5']
# 200
# FL Volusia ['77.3']
# 200
# CA Santa Cruz ['59.4']
# 200
# AL Mobile ['81.0']
# 200
# MA Plymouth ['71.0']
# 200
# FL Martin ['82.9']
# 200
# FL Volusia ['82.9']
# 200
# FL Volusia ['80.3']
# 200
# FL Duval ['78.8']
# 410
# MD Assateague National Seashore ['NaN']
# 410
# NC New Hanover ['NaN']
# 200
# SC Horry ['77.2']
# 410
# FL Apalachicola Bay  ['NaN']
# 429
# 410
# NC New Hanover ['NaN']
# 429
# 410
# FL Gulf ['NaN']
# 429
# 410
# FL Broward ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# LA New Orleans ['85.9']
# 200
# SC Charleston ['82.4']
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# NC Brunswick ['85.0']
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# FL Okaloosa Island ['NaN']
# 429
# 410
# NC New Hanover ['NaN']
# 429
# 200
# FL Volusia ['78.8']
# 200
# CA Los Angeles ['72.1']
# 200
# CA San Luis Obispo ['58.4']
# 200
# SC Charleston ['80.2']
# 410
# DE Sussex ['NaN']
# 429
# 200
# TX Galveston ['82.7']
# 200
# FL Fort Lauderdale ['81.7']
# 410
# NaN nan ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Duval ['75.3']
# 410
# GA Chatham ['NaN']
# 410
# FL Indian River ['NaN']
# 200
# SC Beaufort ['78.7']
# 200
# FL Volusia ['77.5']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['75.1']
# 200
# FL Volusia ['74.3']
# 200
# FL Volusia ['74.3']
# 200
# FL Delray Beach ['74.6']
# 410
# FL Macarthur State Park ['NaN']
# 200
# FL St. Lucie ['66.8']
# 410
# HI Hawaii ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# HI Maui ['NaN']
# 410
# HI Maui ['NaN']
# 200
# OR Lincoln []
# 410
# NJ Ocean ['NaN']
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Kaua'i ['NaN']
# 429
# Error retrieving web page.  Retrying in 10 seconds...
# 200
# FL Miami Beach ['81.3']
# 410
# CA Humboldt ['NaN']
# 410
# FL Okaloosa ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# FL Bay ['NaN']
# 200
# FL Volusia ['78.4']
# 200
# FL Palm Beach ['81.5']
# 410
# FL Escambia ['NaN']
# 200
# FL Volusia ['79.0']
# 200
# SC Beaufort ['79.7']
# 200
# FL Volusia ['78.3']
# Error retrieving web page.  Retrying in 10 seconds...
# 200
# FL Volusia ['78.3']
# 200
# FL Volusia ['80.6']
# 410
# FL Key West Aquarium ['NaN']
# 410
# FL St Johns ['NaN']
# 200
# CA Santa Barbara ['73.7']
# 410
# CA Catalina Channel ['NaN']
# 200
# FL Volusia ['79.2']
# 200
# HI Pohoiki  ['76.8']
# 200
# CA San Mateo ['62.7']
# 410
# HI Maui ['NaN']
# 410
# HI Maui ['NaN']
# 200
# SC Folly Beach ['83.3']
# 200
# FL Lee ['85.0']
# 410
# HI Maui ['NaN']
# 200
# SC Charleston ['80.1']
# 410
# HI Oahu ['NaN']
# 429
# 200
# AL Baldwin ['82.4']
# 200
# FL St. Johns ['82.6']
# 410
# NC Holden Beach. Brunswick County ['NaN']
# 429
# 200
# CA San Mateo ['64.7']
# Error retrieving web page.  Retrying in 10 seconds...
# 200
# FL Duval ['80.6']
# 200
# SC Charleston ['81.0']
# 410
# HI Kona Coast State Park ['NaN']
# 200
# TX Brazoria ['85.1']
# 200
# FL Duval ['78.9']
# 200
# SC Horry ['80.0']
# 410
# FL Monroe ['NaN']
# 410
# HI Oahu ['NaN']
# 200
# FL Volusia ['73.3']
# 200
# CA San Diego ['63.4']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Palm Beach ['77.7']
# 200
# FL Volusia ['76.0']
# 200
# FL Martin ['69.3']
# 500
# HI Kaanapali Shores ['NaN']
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Martin ['62.7']
# 410
# HI Kiholo Bay ['NaN']
# 200
# FL Martin ['50.9']
# 410
# HI Kauai ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Kaua'i ['NaN']
# 429
# 410
# CA Humboldt ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 200
# CA Santa Barbara ['58.6']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['76.3']
# 410
# HI Maui ['NaN']
# 200
# FL Hobe Sound ['79.8']
# 200
# CA Santa Cruz ['56.6']
# 410
# FL Brevard ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['80.6']
# 410
# FL Brevard ['NaN']
# 410
# FL Miami-Dade ['NaN']
# 200
# FL Duval ['80.5']
# 410
# FL St. John's ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['80.6']
# 410
# HI Maui ['NaN']
# 200
# FL Volusia ['80.6']
# 200
# AL Baldwin ['75.9']
# 200
# FL Key Largo ['84.0']
# 200
# CA Los Angeles ['69.9']
# 410
# HI Kauai ['NaN']
# 410
# MA Cape Cod ['NaN']
# 200
# NC Brunswick ['86.3']
# 410
# NC Onslow ['NaN']
# 429
# 200
# CA Santa Cruz ['51.5']
# 200
# FL Palm Beach ['84.6']
# 200
# FL Volusia ['80.4']
# 410
# HI Maui ['NaN']
# 200
# FL Martin ['78.7']
# 200
# SC Horry ['73.5']
# 200
# NC Brunswick ['71.4']
# 410
# FL Monroe ['NaN']
# 429
# 200
# SC Horry ['73.9']
# 200
# SC Horry ['73.9']
# 200
# SC Horry ['73.9']
# 200
# SC Horry ['73.9']
# 200
# FL Volusia ['79.9']
# 200
# SC Horry ['74.1']
# 410
# NC Dare ['NaN']
# 200
# FL Duval ['75.7']
# 410
# HI Oahu ['NaN']
# 200
# CA San Luis Obispo ['51.4']
# 410
# FL Indian River ['NaN']
# 410
# CA Off Catalina Island ['NaN']
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI Oahu ['NaN']
# 429
# 200
# FL Volusia ['75.0']
# 200
# FL Martin ['70.5']
# 200
# FL Volusia ['69.9']
# 200
# FL Volusia ['69.9']
# 410
# FL Brevard ['NaN']
# 200
# FL Palm Beach ['71.5']
# 410
# HI Lanai ['NaN']
# 429
# 200
# OR Lincoln []
# 200
# FL Palm Beach ['66.9']
# 200
# FL New Smyrna Beach ['72.5']
# 410
# HI Kauai ['NaN']
# 429
# 410
# OR Seaside Cove ['NaN']
# 429
# 410
# CA Pigeon Point ['NaN']
# 429
# 200
# OR Lincoln []
# 200
# FL Cape Canaveral ['79.0']
# 200
# OR Seaside ['56.4']
# 200
# FL Manatee ['73.0']
# 200
# AL Baldwin ['56.3']
# 410
# NaN Hatillo Beach ['NaN']
# 429
# 200
# FL Manatee ['83.1']
# 200
# SC Horry ['75.0']
# 410
# HI Kauai ['NaN']
# 429
# 200
# FL New Smyrna Beach ['81.7']
# 410
# CA Humboldt ['NaN']
# 429
# 410
# HI Oahu ['NaN']
# 429
# 200
# FL Volusia ['79.9']
# 410
# FL Crescent Beach St. Johns County ['NaN']
# 429
# 410
# TX Aransas ['NaN']
# 429
# 410
# NC Dare ['NaN']
# 429
# 410
# NC Holden Beach. Brunswick County ['NaN']
# 429
# 200
# NaN  Vieques []
# 200
# SC Horry ['85.1']
# 410
# NC Beaufort Inlet ['NaN']
# 429
# 410
# NJ Atlantic ['NaN']
# 429
# 410
# NC Hyde ['NaN']
# 429
# 200
# TX Cameron ['92.1']
# 410
# TX Calhoun ['NaN']
# 429
# 200
# TX Nueces ['83.2']
# 410
# NC Onslow ['NaN']
# 429
# 200
# CA San Diego ['63.9']
# 410
# FL Escambia ['NaN']
# 429
# 200
# FL Palm Beach ['82.9']
# 200
# CA San Diego ['66.3']
# 200
# FL Volusia ['80.7']
# 200
# TX Brazoria ['84.1']
# 410
# HI Kailua-Kona ['NaN']
# 429
# 410
# HI Kailua-Kona ['NaN']
# 429
# 410
# FL St Johns ['NaN']
# 429
# 200
# FL Volusia ['80.1']
# 200
# FL Miami ['79.0']
# 200
# FL Palm Beach ['82.7']
# 200
# FL Volusia ['75.6']
# 410
# TX Matagorda Beach ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# NaN nan ['NaN']
# 429
# 200
# OR Florence ['51.1']
# 200
# ME Washington ['39.9']
# 200
# CA Santa Barbara ['59.7']
# 200
# OR Winchester Bay ['65.4']
# 410
# VA Sandridge Beach ['NaN']
# 429
# 410
# FL St. John's ['NaN']
# 429
# 200
# FL Volusia ['83.4']
# 200
# FL Volusia ['82.8']
# 200
# FL Volusia ['82.8']
# 410
# FL Crescent Beach St. Johns County ['NaN']
# 200
# CA San Mateo ['60.1']
# 410
# NC New Hanover ['NaN']
# 429
# 200
# FL Volusia ['83.4']
# 200
# CA Santa Barbara ['59.5']
# 200
# FL St. Johns ['84.3']
# 200
# SC Charleston ['84.2']
# 200
# FL Duval ['81.9']
# 200
# SC Myrtle Beach ['83.1']
# 410
# NC New Hanover ['NaN']
# 429
# 200
# FL New Smyrna Beach ['84.1']
# 200
# TX Galveston ['85.4']
# 410
# FL Broward ['NaN']
# 429
# 410
# NY Off Long Island ['NaN']
# 429
# 410
# CA San Luis  Obispo ['NaN']
# 429
# 200
# CA San Onofre ['63.4']
# 200
# TX Galveston ['85.6']
# 410
# SC Fripp Island ['NaN']
# 429
# 200
# NC Pender ['85.4']
# 200
# FL Jacksonville ['82.3']
# 410
# FL Off Tarpon Springs ['NaN']
# 429
# 200
# FL New Smyrna Beach ['78.0']
# 410
# FL Hanalei Bay ['NaN']
# 429
# 410
# HI Kauai ['NaN']
# 429
# 200
# FL Riviera Beach ['69.4']
# 200
# FL Martin ['53.9']
# 410
# FL Elliot Key ['NaN']
# 200
# NJ Camden ['35.3']
# 200
# CA Orange ['63.4']
# 410
# FL Brevard ['NaN']
# 429
# 410
# CA Marin ['NaN']
# 429
# 200
# FL Palm Beach ['69.8']
# 200
# FL Palm Beach ['62.7']
# 200
# FL Volusia ['74.7']
# 200
# CA Santa Cruz ['53.2']
# 200
# CA San Diego ['65.8']
# 410
# HI Maui ['NaN']
# 429
# 200
# CA San Diego ['64.4']
# 410
# FL Monroe ['NaN']
# 429
# 200
# NC Currituck ['71.5']
# 200
# CA Orange ['77.9']
# 200
# CA San Diego ['72.3']
# 200
# FL Volusia ['81.8']
# 410
# HI Kawa'a  ['NaN']
# 429
# 410
# LA Breton Sound ['NaN']
# 429
# 200
# TX South Padre Island ['83.4']
# 410
# NC Holden Beach. Brunswick County ['NaN']
# 429
# 200
# FL St. Petersburg ['83.7']
# 200
# CA San Diego ['70.6']
# 200
# FL Volusia ['82.7']
# 200
# FL Miami ['82.2']
# 200
# CA San Luis Obispo ['56.3']
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Pinellas ['NaN']
# 429
# 200
# FL Volusia ['76.3']
# 200
# FL Volusia ['76.3']
# 200
# FL Volusia ['76.3']
# 410
# FL St. John's ['NaN']
# 200
# CA San Diego ['60.9']
# 200
# FL Volusia ['71.7']
# 410
# FL Jupiter Inlet ['NaN']
# 429
# 410
# HI Kona ['NaN']
# 429
# 410
# CA San Diego County ['NaN']
# 429
# 200
# FL Lee ['68.5']
# 200
# FL Volusia ['68.7']
# 410
# HI Alenuihaha Channel ['NaN']
# 429
# 200
# NaN Quebradillas ['63.9']
# 410
# CA Marin ['NaN']
# 429
# 200
# FL Walton ['78.7']
# 200
# FL Volusia ['76.7']
# 200
# FL Bethune Beach ['76.7']
# 200
# FL Volusia ['82.6']
# 410
# HI Oahu ['NaN']
# 429
# 200
# CA Santa Barbara ['64.6']
# 200
# FL Volusia ['82.9']
# 200
# FL Volusia ['82.9']
# 200
# FL Volusia ['84.9']
# 410
# HI Hawai'i ['NaN']
# 200
# FL Volusia ['82.4']
# 200
# FL Volusia ['82.8']
# 200
# FL Volusia ['79.2']
# 200
# NC Pender ['70.8']
# 200
# FL Lee ['77.3']
# 200
# SC Horry ['75.5']
# 410
# NaN Buck Island ['NaN']
# 200
# FL Volusia ['79.0']
# 410
# HI Oah'u ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Volusia ['80.2']
# 410
# HI Oahu ['NaN']
# 429
# 200
# NC Pender ['76.3']
# 200
# NC Pender ['76.3']
# 200
# FL Volusia ['76.9']
# 200
# FL Volusia ['82.0']
# 410
# NC New Hanover ['NaN']
# 200
# SC Charleston ['78.8']
# 410
# NC Carteret ['NaN']
# 200
# SC Georgetown []
# 410
# HI Hawai'i ['NaN']
# 200
# FL Volusia ['77.1']
# 200
# SC Charleston ['81.5']
# 410
# CA Catalina Island ['NaN']
# 429
# 410
# FL Nassau ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# SC Cherry Grove ['NaN']
# 429
# 410
# NC Onslow ['NaN']
# 429
# 200
# FL Volusia ['74.0']
# 200
# FL Volusia ['73.6']
# 200
# FL Volusia ['71.6']
# 200
# FL Volusia ['70.9']
# 200
# CA San Diego ['61.7']
# 200
# FL Volusia ['71.8']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Palm Beach ['60.7']
# 200
# FL Volusia ['69.3']
# 200
# FL Volusia ['73.0']
# 200
# FL Volusia ['67.7']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['69.2']
# 200
# FL Volusia ['66.2']
# 200
# FL Lee ['67.0']
# 200
# CA Orange ['62.0']
# 200
# FL Volusia ['57.2']
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI O'ahu ['NaN']
# 429
# 200
# FL Volusia ['62.8']
# 410
# FL Indian River ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# CA Los Angeles ['67.1']
# 410
# FL Brevard ['NaN']
# 429
# 200
# CA Los Angeles ['68.9']
# 410
# CA Humboldt ['NaN']
# 429
# 410
# FL Jupiter Inlet ['NaN']
# 429
# 410
# FL Huguenot Park ['NaN']
# 429
# 200
# FL Volusia ['78.3']
# 200
# FL Volusia ['81.0']
# 410
# FL Flagler ['NaN']
# 429
# 410
# FL Broward ['NaN']
# 429
# 200
# FL St. Lucie ['79.4']
# 200
# FL Volusia ['81.3']
# 410
# SC Sullivan's Island ['NaN']
# 429
# 200
# FL Volusia ['78.2']
# 410
# FL Broward ['NaN']
# 429
# 410
# HI Oahu ['NaN']
# 429
# 200
# CA Monterey ['63.6']
# 200
# FL Volusia ['80.3']
# 200
# FL Volusia ['82.4']
# 410
# NC North Carolina Aquarium at Fort Fisher ['NaN']
# 429
# 200
# DE Rehoboth Beach ['70.2']
# 410
# FL Monroe ['NaN']
# 429
# 200
# FL Volusia ['84.1']
# 410
# FL Sarasota Bay ['NaN']
# 429
# 200
# FL Volusia ['84.2']
# 200
# FL Volusia ['85.4']
# 200
# SC Charleston ['85.8']
# 200
# SC Charleston ['85.8']
# 410
# FL Monroe ['NaN']
# 200
# FL Volusia ['79.9']
# 200
# CA San Diego ['72.4']
# 200
# CA Los Angeles ['72.2']
# 200
# CA San Mateo ['65.9']
# 500
# HI Oahu ['NaN']
# 429
# 410
# NC Onslow ['NaN']
# 429
# 200
# CA Ventura ['63.9']
# 410
# NC Carteret ['NaN']
# 429
# 200
# FL Volusia ['79.9']
# 410
# FL Marques Island ['NaN']
# 429
# 200
# CA Los Angeles ['72.8']
# 200
# FL Volusia ['80.9']
# 410
# HI O'ahu ['NaN']
# 429
# 410
# FL St.  Johns ['NaN']
# 429
# 200
# FL Sarasota ['80.9']
# 200
# SC Garden City ['71.5']
# 200
# VA Virginia Beach ['64.0']
# 200
# FL Volusia ['71.6']
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Naples ['73.5']
# 200
# FL St. Lucie ['69.0']
# 200
# FL Volusia ['65.9']
# 410
# FL Monroe ['NaN']
# 429
# 200
# FL Volusia ['69.0']
# 200
# FL St. Lucie ['72.2']
# 200
# FL St. Lucie ['72.2']
# 410
# FL Jupiter Inlet ['NaN']
# 200
# FL Delray Beach ['73.3']
# 200
# FL Martin ['63.9']
# 410
# FL 100 miles off Ft. Myers Beach ['NaN']
# 429
# 410
# NY Long Island ['NaN']
# 429
# 410
# HI Kaua'i ['NaN']
# 429
# 410
# CA Marin ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# OR Lincoln []
# 410
# FL Sebastian Inlet ['NaN']
# 200
# FL Volusia ['69.8']
# 200
# TX South Padre Island ['79.3']
# 200
# FL Volusia ['81.9']
# 200
# FL Volusia ['76.3']
# 410
# FL Monroe ['NaN']
# 429
# 410
# NC Onslow Beach ['NaN']
# 429
# 200
# FL Riviera Beach ['82.8']
# 200
# FL Volusia ['82.7']
# 200
# FL Volusia ['79.6']
# 200
# FL Volusia ['78.8']
# 410
# OR Lane ['NaN']
# 429
# 200
# KY Newport ['80.2']
# 410
# OR Oswald State Park ['NaN']
# 429
# 200
# CA Los Angeles ['77.2']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['82.9']
# 200
# TX Matagorda ['83.6']
# 200
# SC Beaufort ['86.1']
# 200
# SC Charleston ['81.9']
# 200
# FL Volusia ['75.2']
# 410
# FL St Johns ['NaN']
# 429
# 200
# SC Georgetown []
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Monroe ['NaN']
# 429
# 410
# FL Monroe ['NaN']
# 429
# 200
# FL St. Lucie ['79.6']
# 200
# FL Fort Myers ['79.1']
# 200
# FL Volusia ['81.9']
# 200
# CA Monterey ['60.5']
# 200
# FL Volusia ['86.2']
# 200
# SC Beaufort ['79.0']
# 410
# HI O'ahu ['NaN']
# 429
# 410
# HI French Frigate Shoals ['NaN']
# 429
# 410
# HI O'ahu ['NaN']
# 429
# 410
# HI Lanai ['NaN']
# 429
# 410
# NaN Gun Beach ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL St. Lucie ['73.6']
# 410
# FL Monroe ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['73.6']
# 410
# FL Collier ['NaN']
# 429
# 410
# FL Collier ['NaN']
# 429
# 410
# HI O'ahu ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 200
# CA Santa Cruz ['50.5']
# 410
# FL Indian River ['NaN']
# 429
# 410
# OR Clatsop ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# FL Gulf ['NaN']
# 429
# 200
# FL Volusia ['67.8']
# 200
# FL Martin ['69.9']
# 200
# FL Volusia ['68.0']
# 200
# FL Volusia ['70.5']
# 200
# CA San Mateo ['58.2']
# 200
# CA San Francisco ['57.3']
# 200
# FL Volusia ['67.1']
# 410
# CA Del Norte ['NaN']
# 429
# 200
# CA Sonoma ['61.8']
# 200
# FL Volusia ['79.5']
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Volusia ['78.6']
# 410
# FL Collier ['NaN']
# 429
# 200
# SC Horry ['79.6']
# 200
# SC Folly Beach ['75.9']
# 410
# NC Onslow ['NaN']
# 429
# 200
# FL Volusia ['83.5']
# 200
# CA San Diego ['67.8']
# 200
# SC Horry ['83.9']
# 200
# SC Horry ['87.1']
# 410
# TX Crystal Beach (east of Galveston) ['NaN']
# 429
# 410
# NC New Hanover ['NaN']
# 429
# 200
# SC Charleston ['80.3']
# 200
# FL Volusia ['86.5']
# 200
# FL Volusia ['83.2']
# 200
# FL Volusia ['85.6']
# 200
# NC Brunswick ['82.2']
# 200
# TX Galveston ['90.6']
# 200
# FL Lee ['83.9']
# 410
# FL Gulf ['NaN']
# 429
# 200
# FL Walton ['83.9']
# 410
# HI Maui ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# SC Charleston ['77.6']
# 410
# NJ Ocean ['NaN']
# 429
# 200
# TX Corpus Christi ['78.6']
# 200
# FL Daytona Beach Shores ['78.9']
# 410
# FL Pinellas ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# SC Off Sullivans Island ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Sarasota ['72.9']
# 410
# FL St. John ['NaN']
# 429
# 200
# TX Cameron ['63.7']
# 200
# FL Duval ['67.1']
# 410
# NM Albuquerue ['NaN']
# 429
# 410
# FL Monroe ['NaN']
# 429
# 410
# HI north shore of O'ahu ['NaN']
# 429
# 200
# FL Fort Lauderdale ['61.6']
# 410
# CA Humboldt ['NaN']
# 429
# 410
# CA Point Reyes National Seashore ['NaN']
# 429
# 410
# HI Moloka'i ['NaN']
# 429
# 200
# CA San Luis Obispo ['65.3']
# 200
# CA Orange ['66.8']
# 410
# OR Gold  Beach ['NaN']
# 429
# 200
# TX South Padre Island ['83.2']
# 200
# SC Horry ['76.9']
# 410
# FL Brevard ['NaN']
# 429
# 200
# CA Orange ['68.7']
# 200
# CA Mendocino ['57.3']
# 410
# FL Pinellas ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# NC Dare ['NaN']
# 429
# 410
# NC New Hanover ['NaN']
# 429
# 410
# TX Galveston Island ['NaN']
# 429
# 200
# TX Brazoria ['82.8']
# 200
# AL Baldwin ['79.2']
# 200
# CA San Diego ['67.3']
# 410
# FL Indian River ['NaN']
# 429
# 200
# FL Volusia ['78.2']
# 410
# TX Galveston Island ['NaN']
# 429
# 200
# CA Sonoma ['61.8']
# 410
# FL St. John's ['NaN']
# 429
# 410
# FL St. Augustine  St. Johns County ['NaN']
# 429
# 200
# FL Duval ['78.9']
# 410
# TX Channel between South Padre Island & Padre Island National Seashore ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Velzyland ['NaN']
# 429
# 200
# FL Palm Beach ['72.0']
# 200
# FL Martin ['65.1']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Lee ['65.6']
# 200
# HI Punaluu ['73.1']
# 410
# HI Kauai ['NaN']
# 429
# 410
# FL Dade ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['65.4']
# 200
# FL Volusia ['74.3']
# 200
# FL St. Johns ['74.7']
# 410
# HI Kaua'i ['NaN']
# 429
# 200
# FL Volusia ['78.6']
# 410
# HI Honolua Bay ['NaN']
# 429
# 410
# FL Near Patrick Air Force Base Brevard County ['NaN']
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 200
# FL Palm Beach? ['77.6']
# 200
# FL Palm Beach ['80.7']
# 200
# FL Martin ['74.7']
# 200
# FL Volusia ['78.5']
# 200
# FL Volusia ['78.5']
# 410
# HI Maui ['NaN']
# 410
# FL St. Lucie Couny ['NaN']
# 429
# 200
# FL Volusia ['80.8']
# 200
# FL Volusia ['79.2']
# 200
# FL Volusia ['79.2']
# 200
# FL Volusia ['80.5']
# 200
# FL Martin ['80.2']
# 200
# FL Volusia ['79.7']
# 200
# SC Charleston ['72.5']
# 410
# TX 1.5 miles off Surfside  ['NaN']
# 429
# 200
# CA San Luis Obispo ['63.2']
# 200
# CA Los Angeles ['78.8']
# 200
# FL Volusia ['81.8']
# 200
# FL Volusia ['78.9']
# 200
# FL Volusia ['82.0']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['81.3']
# 410
# FL St Augustine Beach. St. Johns County ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# HI Oahu ['NaN']
# 429
# 410
# NaN nan ['NaN']
# 429
# 410
# NC New Hanover ['NaN']
# 429
# 200
# FL Volusia ['78.7']
# 200
# FL Palm Beach ['77.6']
# 200
# FL Volusia ['78.0']
# 410
# HI Between Magic Sands Beach and Kahaluu Beach on the Kona coast ['NaN']
# 429
# 200
# FL Volusia ['81.8']
# 200
# FL Volusia ['77.3']
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['73.6']
# 200
# FL Volusia ['73.6']
# 200
# FL Volusia ['73.4']
# 410
# FL Brevard ['NaN']
# 410
# FL Brevard ['NaN']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['70.8']
# 410
# FL Hillsborough ['NaN']
# 429
# 200
# FL Palm Beach ['72.5']
# 200
# CA Sonoma ['49.5']
# 410
# HI Ka'anapali ['NaN']
# 429
# 200
# FL Volusia ['76.2']
# 200
# FL Volusia ['65.6']
# 410
# HI Maui ['NaN']
# 410
# FL Brevard ['NaN']
# 429
# 200
# FL Volusia ['79.7']
# 200
# FL Volusia ['79.7']
# 200
# FL Volusia ['78.8']
# 200
# FL Volusia ['82.2']
# 410
# FL Brevard ['NaN']
# 410
# HI O'ahu ['NaN']
# 429
# 410
# FL Monroe ['NaN']
# 429
# 410
# OR Cape Kiwanda ['NaN']
# 410
# CA Humboldt ['NaN']
# 429
# 410
# HI Kaua'i ['NaN']
# 429
# 200
# FL Volusia ['81.9']
# 200
# FL Volusia ['78.5']
# 410
# HI O'ahu ['NaN']
# 429
# 410
# AL 65 miles offshore from Mobile ['NaN']
# 429
# 200
# FL Volusia ['77.8']
# 410
# FL Indian River ['NaN']
# 429
# 200
# FL Volusia ['81.3']
# 200
# NC Pender ['80.5']
# 200
# SC Horry ['82.7']
# 410
# NC Carteret ['NaN']
# 200
# FL Volusia ['78.3']
# 410
# MD in 7000' of water ['NaN']
# 410
# NC New Hanover ['NaN']
# 429
# 200
# FL Volusia ['75.5']
# 410
# HI Kaua'i ['NaN']
# 429
# 410
# FL St Johns ['NaN']
# 429
# 200
# FL Volusia ['79.4']
# 200
# FL Martin ['78.9']
# 410
# CA Marin ['NaN']
# 200
# FL Franklin ['73.8']
# 200
# FL Marco Island ['76.6']
# 200
# FL Palm Beach ['74.8']
# 410
# FL Collier ['NaN']
# 200
# FL St. Johns ['79.2']
# 200
# FL Volusia ['77.2']
# 200
# FL Volusia ['72.7']
# 410
# FL Broward ['NaN']
# 410
# HI Kaua'i ['NaN']
# 410
# FL Brevard ['NaN']
# 200
# FL Volusia ['74.5']
# 410
# FL Broward ['NaN']
# 429
# 200
# FL Volusia ['68.8']
# 410
# HI Maui ['NaN']
# 429
# 410
# HI Maui ['NaN']
# 429
# 200
# FL Volusia ['78.9']
# 200
# FL Volusia ['76.9']
# 410
# FL Broward ['NaN']
# 429
# 410
# FL A quarter mile north of Fort Pierce Inlet ['NaN']
# 429
# 410
# NC Onslow ['NaN']
# 429
# 410
# FL Monroe ['NaN']
# 429
# 410
# FL Dade ['NaN']
# 429
# 200
# SC Horry ['75.8']
# 410
# NC Dare ['NaN']
# 410
# NC Dare ['NaN']
# 429
# 410
# FL Duval Country ['NaN']
# 200
# VA Princess Anne ['76.5']
# 200
# FL Manatee ['84.0']
# 200
# FL Volusia ['80.7']
# 200
# FL Volusia ['80.5']
# 200
# FL Volusia ['81.4']
# 200
# FL Volusia ['80.8']
# 200
# FL Volusia ['80.0']
# 200
# FL Volusia ['81.8']
# 200
# FL Volusia ['81.8']
# 200
# FL Volusia ['81.8']
# 200
# FL Volusia ['82.5']
# 200
# FL Volusia ['82.5']
# 200
# FL Volusia ['82.5']
# 200
# SC Horry ['79.3']
# 200
# SC Horry ['79.5']
# 410
# FL Monroe ['NaN']
# 410
# FL Monroe ['NaN']
# 410
# MA Chatham Island ['NaN']
# 410
# FL Escambia ['NaN']
# 410
# FL Nassau ['NaN']
# 410
# FL Gulf Islands National Seashore ['NaN']
# 200
# SC Charleston ['81.4']
# 410
# TX Padre Island National Seashore ['NaN']
# 410
# CA Catalina Island ['NaN']
# 200
# SC Charleston ['78.9']
# 410
# TX Galveston Island ['NaN']
# 429
# 200
# SC Beaufort ['76.2']
# 200
# FL Duval ['69.5']
# 200
# FL Volusia ['68.2']
# 200
# FL Volusia ['77.9']
# 200
# FL Volusia ['77.9']
# 410
# FL St Lucie ['NaN']
# 200
# FL Volusia ['77.9']
# 200
# FL Volusia ['77.9']
# 200
# FL Volusia ['77.9']
# 200
# FL Volusia ['77.9']
# 200
# FL Volusia ['76.9']
# 200
# FL Volusia ['76.9']
# 410
# HI O'ahu ['NaN']
# 200
# FL Volusia ['73.6']
# 200
# FL Volusia ['70.7']
# 410
# HI Oahu ['NaN']
# 200
# FL Martin ['51.6']
# 200
# CA San Diego ['55.1']
# 200
# FL Lee ['50.7']
# 410
# FL Flagler ['NaN']
# 410
# CA Humboldt ['NaN']
# 410
# FL St Lucie ['NaN']
# 200
# HI Olowalu ['77.8']
# 410
# FL Indian River ['NaN']
# 200
# FL Palm Beach ['75.0']
# 200
# FL Volusia ['80.5']
# 200
# FL Volusia ['80.5']
# 410
# NC New Hanover ['NaN']
# 200
# CA San Mateo ['60.2']
# 200
# SC Charleston ['73.8']
# 410
# FL St Lucie ['NaN']
# 410
# FL Indian River or Brevard ['NaN']
# 200
# FL Volusia ['80.2']
# 410
# FL Indian River ['NaN']
# 200
# FL Volusia ['78.8']
# 200
# FL Volusia ['80.4']
# 410
# FL Pinellas ['NaN']
# 410
# AK Prince William Sound ['NaN']
# 429
# 410
# NC Carteret ['NaN']
# 429
# Error retrieving web page.  Retrying in 10 seconds...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda2/envs/python36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-8d19bc142292> in <module>
# ----> 1 temp=get_temperature(list_state,list_city,list_date)
#
# <ipython-input-61-285cf77f486b> in get_temperature(state, city, date)
#       7         while tree is None:
#       8             try:
# ----> 9                 r=requests.get(url)
#      10                 print(r.status_code)
#      11                 if(r.status_code==200):
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda2/envs/python36/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda2/envs/python36/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda2/envs/python36/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda2/envs/python36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda2/envs/python36/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
list_city
# Out:
# ['San Diego',
#  'Glynn',
#  'Oahu',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  'Charleston',
#  'Beaufort',
#  'Kauai',
#  'Kukio Beach',
#  'Oahu',
#  'Marin',
#  'Monterey',
#  'Brevard',
#  'Oahu',
#  'Palm Beach',
#  'Palm Beach',
#  'Palm Beach',
#  'Kauai',
#  'Maui',
#  'Duval',
#  'Rockaway',
#  'Fort Worth',
#  'Palm Beach County',
#  'Volusia',
#  'Volusia',
#  'Monroe',
#  'Cameron',
#  'Volusia',
#  'Bathtub Beach ',
#  'Barnstable',
#  'Beaufort',
#  'Barnstable',
#  'San Mateo',
#  'Duval',
#  'Beaufort',
#  'Georgetown',
#  'Ventnor',
#  'Monroe',
#  'Beaufort',
#  'Santa Barbara',
#  'Santa Barbara',
#  'Grays Harbor',
#  'Santa Cruz',
#  'Miami-Dade',
#  'Wrightsville Beach',
#  'Beaufort',
#  'Palm Beach',
#  'Beaufort',
#  'Volusia',
#  'Monroe',
#  'Charleston',
#  'Off Jupiter',
#  'Orange',
#  'San Diego',
#  'Charleston',
#  'nan',
#  'Georgetown County',
#  'Volusia',
#  'Kauai',
#  'Duval',
#  'St. Augustine',
#  'Volusia',
#  'Brevard',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'Okaloosa',
#  'Volusia',
#  'Monterey Bay',
#  'Brevard',
#  '16 miles off Hilton Head',
#  'Indian River',
#  'Jensen Beach',
#  'Brevard',
#  'St Lucie',
#  'Volusia',
#  'Maui',
#  'Duval',
#  'Mayport Naval Station  Duval County',
#  'Maui',
#  'Maui',
#  'Clatsop',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Humboldt',
#  'St. Johns',
#  'Oahu',
#  'Horry',
#  'Volusia',
#  'Santa Barbara',
#  'Volusia',
#  'Volusia',
#  'St. Johns',
#  'Maui',
#  'Volusia',
#  'Monroe',
#  '8 miles off Mobile',
#  'Volusia',
#  'Volusia',
#  'Orange',
#  'Horry',
#  'Santa Cruz',
#  'Essec',
#  'Los Angeles',
#  'Brevard',
#  "Sullivan's Island",
#  'Carteret',
#  'Horry',
#  'Brevard',
#  'Kauai',
#  'Galveston',
#  'Carteret',
#  'Charleston',
#  'Flagler',
#  'Orange',
#  'Duval',
#  'Indian River',
#  'Pinellas',
#  'Duval',
#  'St. Johns',
#  'Palm Beach',
#  'Maui',
#  'Volusia',
#  'Palm Beach',
#  'Monroe',
#  'Palm Beach',
#  'Maui',
#  'Lee',
#  'Orange',
#  'St. Lucie',
#  'Palm Beach',
#  'Kauai',
#  '',
#  'Off Surfside',
#  'Maui',
#  "La'aloa Beach Park",
#  'Brevard',
#  'Palm Beach',
#  'Palm Beach',
#  'Brevard',
#  'Hawaii',
#  'Brevard',
#  'Oahu',
#  'Brevard',
#  'Broward',
#  '',
#  'Oahu',
#  'San Luis Obispo',
#  'Beaufort',
#  'Oahu',
#  'St. Lucie',
#  'Galveston',
#  'Volusia',
#  'St.  Johns',
#  'Santa Barbara',
#  'Volusia',
#  'Big Island',
#  'Nassau',
#  'St.  Johns',
#  'Santa Barbara',
#  'Duval',
#  'Duval',
#  'Los Angeles',
#  'Ventura',
#  'Horry',
#  'San Luis Obispo',
#  'San Luis Obispo',
#  'Brevard',
#  'Georgetown',
#  'Duval',
#  'Santa Barbara County',
#  'Cortes Bank',
#  'Volusia',
#  'Colleton',
#  'San Diego',
#  'Orange',
#  'Orange',
#  'Pender',
#  'Hyde',
#  'Charleston',
#  'Dare',
#  'Duval',
#  'Beaufort',
#  'Dare',
#  'Surf City',
#  'Beaufort',
#  'Daytona Beach Shores',
#  'Brunswick',
#  'Brunswick',
#  'Off San Diego',
#  'Brunswick',
#  'Brevard',
#  'Fort Lauderdale',
#  'Brevard',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  "Sullivan's Island",
#  'Brevard',
#  'Kanahena Cove ',
#  'Marco Island',
#  'Monroe',
#  'Palm Beach',
#  'Hapuna Beach',
#  'Lahaina',
#  'Off Panama City',
#  'nan',
#  'Indian River',
#  'San Luis Obispo',
#  'San Mateo',
#  'Brevard',
#  'West Maui',
#  'St. Lucie',
#  'Hawaii',
#  'Maui',
#  'Maui',
#  'Santa Barbara',
#  'South Maui',
#  'Beaufort',
#  'Brevard',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  'Santa Barbara County',
#  'Santa Barbara County',
#  'Santa Barbara',
#  'Volusia',
#  'Santa Cruz',
#  'Mobile',
#  'Plymouth',
#  'Martin',
#  'Volusia',
#  'Volusia',
#  'Duval',
#  'Assateague National Seashore',
#  'New Hanover',
#  'Horry',
#  'Apalachicola Bay ',
#  'New Hanover',
#  'Gulf',
#  'Broward',
#  'Brevard',
#  'New Orleans',
#  'Charleston',
#  'Brevard',
#  'Brevard',
#  'Brevard',
#  'Brunswick',
#  'Brevard',
#  'Maui',
#  'Okaloosa Island',
#  'New Hanover',
#  'Volusia',
#  'Los Angeles',
#  'San Luis Obispo',
#  'Charleston',
#  'Sussex',
#  'Galveston',
#  'Fort Lauderdale',
#  'nan',
#  'Brevard',
#  'Duval',
#  'Chatham',
#  'Indian River',
#  'Beaufort',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Delray Beach',
#  'Macarthur State Park',
#  'St. Lucie',
#  'Hawaii',
#  'Brevard',
#  'Maui',
#  'Maui',
#  'Lincoln',
#  'Ocean',
#  'Brevard',
#  'Maui',
#  'Maui',
#  "Kaua'i",
#  'Miami Beach',
#  'Humboldt',
#  'Okaloosa',
#  'Brevard',
#  'Bay',
#  'Volusia',
#  'Palm Beach',
#  'Escambia',
#  'Volusia',
#  'Beaufort',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Key West Aquarium',
#  'St Johns',
#  'Santa Barbara',
#  'Catalina Channel',
#  'Volusia',
#  'Pohoiki ',
#  'San Mateo',
#  'Maui',
#  'Maui',
#  'Folly Beach',
#  'Lee',
#  'Maui',
#  'Charleston',
#  'Oahu',
#  'Baldwin',
#  'St. Johns',
#  'Holden Beach. Brunswick County',
#  'San Mateo',
#  'Duval',
#  'Charleston',
#  'Kona Coast State Park',
#  'Brazoria',
#  'Duval',
#  'Horry',
#  'Monroe',
#  'Oahu',
#  'Volusia',
#  'San Diego',
#  'Brevard',
#  'Palm Beach',
#  'Volusia',
#  'Martin',
#  'Ka\x92anapali Shores',
#  'Maui',
#  'Maui',
#  'Martin',
#  'Kiholo Bay',
#  'Martin',
#  'Kauai',
#  'Maui',
#  'Brevard',
#  'Maui',
#  "Kaua'i",
#  'Humboldt',
#  'Maui',
#  'Santa Barbara',
#  'Brevard',
#  'Volusia',
#  'Maui',
#  'Hobe Sound',
#  'Santa Cruz',
#  'Brevard',
#  'Brevard',
#  'Brevard',
#  'Volusia',
#  'Brevard',
#  'Miami-Dade',
#  'Duval',
#  "St. John's",
#  'Brevard',
#  'Volusia',
#  'Maui',
#  'Volusia',
#  'Baldwin',
#  'Key Largo',
#  'Los Angeles',
#  'Kauai',
#  'Cape Cod',
#  'Brunswick',
#  'Onslow',
#  'Santa Cruz',
#  'Palm Beach',
#  'Volusia',
#  'Maui',
#  'Martin',
#  'Horry',
#  'Brunswick',
#  'Monroe',
#  'Horry',
#  'Horry',
#  'Horry',
#  'Horry',
#  'Volusia',
#  'Horry',
#  'Dare',
#  'Duval',
#  'Oahu',
#  'San Luis Obispo',
#  'Indian River',
#  'Off Catalina Island',
#  'Brevard',
#  'Oahu',
#  'Volusia',
#  'Martin',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  'Palm Beach',
#  'Lanai',
#  'Lincoln',
#  'Palm Beach',
#  'New Smyrna Beach',
#  'Kauai',
#  'Seaside Cove',
#  'Pigeon Point',
#  'Lincoln',
#  'Cape Canaveral',
#  'Seaside',
#  'Manatee',
#  'Baldwin',
#  'Hatillo Beach',
#  'Manatee',
#  'Horry',
#  'Kauai',
#  'New Smyrna Beach',
#  'Humboldt',
#  'Oahu',
#  'Volusia',
#  'Crescent Beach St. Johns County',
#  'Aransas',
#  'Dare',
#  'Holden Beach. Brunswick County',
#  ' Vieques',
#  'Horry',
#  'Beaufort Inlet',
#  'Atlantic',
#  'Hyde',
#  'Cameron',
#  'Calhoun',
#  'Nueces',
#  'Onslow',
#  'San Diego',
#  'Escambia',
#  'Palm Beach',
#  'San Diego',
#  'Volusia',
#  'Brazoria',
#  'Kailua-Kona',
#  'Kailua-Kona',
#  'St Johns',
#  'Volusia',
#  'Miami',
#  'Palm Beach',
#  'Volusia',
#  'Matagorda Beach',
#  'Maui',
#  'Maui',
#  'nan',
#  'Florence',
#  'Washington',
#  'Santa Barbara',
#  'Winchester Bay',
#  'Sandridge Beach',
#  "St. John's",
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Crescent Beach St. Johns County',
#  'San Mateo',
#  'New Hanover',
#  'Volusia',
#  'Santa Barbara',
#  'St. Johns',
#  'Charleston',
#  'Duval',
#  'Myrtle Beach',
#  'New Hanover',
#  'New Smyrna Beach',
#  'Galveston',
#  'Broward',
#  'Off Long Island',
#  'San Luis  Obispo',
#  'San Onofre',
#  'Galveston',
#  'Fripp Island',
#  'Pender',
#  'Jacksonville',
#  'Off Tarpon Springs',
#  'New Smyrna Beach',
#  'Hanalei Bay',
#  'Kauai',
#  'Riviera Beach',
#  'Martin',
#  'Elliot Key',
#  'Camden',
#  'Orange',
#  'Brevard',
#  'Marin',
#  'Palm Beach',
#  'Palm Beach',
#  'Volusia',
#  'Santa Cruz',
#  'San Diego',
#  'Maui',
#  'San Diego',
#  'Monroe',
#  'Currituck',
#  'Orange',
#  'San Diego',
#  'Volusia',
#  "Kawa'a ",
#  'Breton Sound',
#  'South Padre Island',
#  'Holden Beach. Brunswick County',
#  'St. Petersburg',
#  'San Diego',
#  'Volusia',
#  'Miami',
#  'San Luis Obispo',
#  'Brevard',
#  'Pinellas',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  "St. John's",
#  'San Diego',
#  'Volusia',
#  'Jupiter Inlet',
#  'Kona',
#  'San Diego County',
#  'Lee',
#  'Volusia',
#  'Alenuihaha Channel',
#  'Quebradillas',
#  'Marin',
#  'Walton',
#  'Volusia',
#  'Bethune Beach',
#  'Volusia',
#  'Oahu',
#  'Santa Barbara',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  "Hawai'i",
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Pender',
#  'Lee',
#  'Horry',
#  'Buck Island',
#  'Volusia',
#  "Oah'u",
#  'Maui',
#  'Volusia',
#  'Oahu',
#  'Pender',
#  'Pender',
#  'Volusia',
#  'Volusia',
#  'New Hanover',
#  'Charleston',
#  'Carteret',
#  'Georgetown',
#  "Hawai'i",
#  'Volusia',
#  'Charleston',
#  'Catalina Island',
#  'Nassau',
#  'Brevard',
#  'Cherry Grove',
#  'Onslow',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'San Diego',
#  'Volusia',
#  'Brevard',
#  'Palm Beach',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'Lee',
#  'Orange',
#  'Volusia',
#  'Brevard',
#  'Brevard',
#  "O'ahu",
#  'Volusia',
#  'Indian River',
#  'Maui',
#  'Los Angeles',
#  'Brevard',
#  'Los Angeles',
#  'Humboldt',
#  'Jupiter Inlet',
#  'Huguenot Park',
#  'Volusia',
#  'Volusia',
#  'Flagler',
#  'Broward',
#  'St. Lucie',
#  'Volusia',
#  "Sullivan's Island",
#  'Volusia',
#  'Broward',
#  'Oahu',
#  'Monterey',
#  'Volusia',
#  'Volusia',
#  'North Carolina Aquarium at Fort Fisher',
#  'Rehoboth Beach',
#  'Monroe',
#  'Volusia',
#  'Sarasota Bay',
#  'Volusia',
#  'Volusia',
#  'Charleston',
#  'Charleston',
#  'Monroe',
#  'Volusia',
#  'San Diego',
#  'Los Angeles',
#  'San Mateo',
#  'O\x92ahu',
#  'Onslow',
#  'Ventura',
#  'Carteret',
#  'Volusia',
#  'Marques Island',
#  'Los Angeles',
#  'Volusia',
#  "O'ahu",
#  'St.  Johns',
#  'Sarasota',
#  'Garden City',
#  'Virginia Beach',
#  'Volusia',
#  'Maui',
#  'Naples',
#  'St. Lucie',
#  'Volusia',
#  'Monroe',
#  'Volusia',
#  'St. Lucie',
#  'St. Lucie',
#  'Jupiter Inlet',
#  'Delray Beach',
#  'Martin',
#  '100 miles off Ft. Myers Beach',
#  'Long Island',
#  "Kaua'i",
#  'Marin',
#  'Maui',
#  'Lincoln',
#  'Sebastian Inlet',
#  'Volusia',
#  'South Padre Island',
#  'Volusia',
#  'Volusia',
#  'Monroe',
#  'Onslow Beach',
#  'Riviera Beach',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Lane',
#  'Newport',
#  'Oswald State Park',
#  'Los Angeles',
#  'Brevard',
#  'Volusia',
#  'Matagorda',
#  'Beaufort',
#  'Charleston',
#  'Volusia',
#  'St Johns',
#  'Georgetown',
#  'Brevard',
#  'Monroe',
#  'Monroe',
#  'St. Lucie',
#  'Fort Myers',
#  'Volusia',
#  'Monterey',
#  'Volusia',
#  'Beaufort',
#  "O'ahu",
#  'French Frigate Shoals',
#  "O'ahu",
#  'Lanai',
#  'Gun Beach',
#  'Brevard',
#  'St. Lucie',
#  'Monroe',
#  'Brevard',
#  'Volusia',
#  'Collier',
#  'Collier',
#  "O'ahu",
#  'Maui',
#  'Maui',
#  'Maui',
#  'Santa Cruz',
#  'Indian River',
#  'Clatsop',
#  'Maui',
#  'Gulf',
#  'Volusia',
#  'Martin',
#  'Volusia',
#  'Volusia',
#  'San Mateo',
#  'San Francisco',
#  'Volusia',
#  'Del Norte',
#  'Sonoma',
#  'Volusia',
#  'Maui',
#  'Volusia',
#  'Collier',
#  'Horry',
#  'Folly Beach',
#  'Onslow',
#  'Volusia',
#  'San Diego',
#  'Horry',
#  'Horry',
#  'Crystal Beach (east of Galveston)',
#  'New Hanover',
#  'Charleston',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Brunswick',
#  'Galveston',
#  'Lee',
#  'Gulf',
#  'Walton',
#  'Maui',
#  'Brevard',
#  'Charleston',
#  'Ocean',
#  'Corpus Christi',
#  'Daytona Beach Shores',
#  'Pinellas',
#  'Maui',
#  'Off Sullivans Island',
#  'Maui',
#  'Sarasota',
#  'St. John',
#  'Cameron',
#  'Duval',
#  'Albuquerue',
#  'Monroe',
#  "north shore of O'ahu",
#  'Fort Lauderdale',
#  'Humboldt',
#  'Point Reyes National Seashore',
#  "Moloka'i",
#  'San Luis Obispo',
#  'Orange',
#  'Gold  Beach',
#  'South Padre Island',
#  'Horry',
#  'Brevard',
#  'Orange',
#  'Mendocino',
#  'Pinellas',
#  'Brevard',
#  'Dare',
#  'New Hanover',
#  'Galveston Island',
#  'Brazoria',
#  'Baldwin',
#  'San Diego',
#  'Indian River',
#  'Volusia',
#  'Galveston Island',
#  'Sonoma',
#  "St. John's",
#  'St. Augustine  St. Johns County',
#  'Duval',
#  'Channel between South Padre Island & Padre Island National Seashore',
#  'Maui',
#  'Velzyland',
#  'Palm Beach',
#  'Martin',
#  'Brevard',
#  'Lee',
#  'Punaluu',
#  'Kauai',
#  'Dade',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'St. Johns',
#  "Kaua'i",
#  'Volusia',
#  'Honolua Bay',
#  'Near Patrick Air Force Base Brevard County',
#  'Palm Beach?',
#  'Palm Beach',
#  'Martin',
#  'Volusia',
#  'Volusia',
#  'Maui',
#  'St. Lucie Couny',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Martin',
#  'Volusia',
#  'Charleston',
#  '1.5 miles off Surfside ',
#  'San Luis Obispo',
#  'Los Angeles',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  'Volusia',
#  'St Augustine Beach. St. Johns County',
#  'Brevard',
#  'Oahu',
#  'nan',
#  'New Hanover',
#  'Volusia',
#  'Palm Beach',
#  'Volusia',
#  'Between Magic Sands Beach and Kahaluu Beach on the Kona coast',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  'Brevard',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  'Brevard',
#  'Brevard',
#  'Volusia',
#  'Hillsborough',
#  'Palm Beach',
#  'Sonoma',
#  "Ka'anapali",
#  'Volusia',
#  'Volusia',
#  'Maui',
#  'Brevard',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Brevard',
#  "O'ahu",
#  'Monroe',
#  'Cape Kiwanda',
#  'Humboldt',
#  "Kaua'i",
#  'Volusia',
#  'Volusia',
#  "O'ahu",
#  '65 miles offshore from Mobile',
#  'Volusia',
#  'Indian River',
#  'Volusia',
#  'Pender',
#  'Horry',
#  'Carteret',
#  'Volusia',
#  "in 7000' of water",
#  'New Hanover',
#  'Volusia',
#  "Kaua'i",
#  'St Johns',
#  'Volusia',
#  'Martin',
#  'Marin',
#  'Franklin',
#  'Marco Island',
#  'Palm Beach',
#  'Collier',
#  'St. Johns',
#  'Volusia',
#  'Volusia',
#  'Broward',
#  "Kaua'i",
#  'Brevard',
#  'Volusia',
#  'Broward',
#  'Volusia',
#  'Maui',
#  'Maui',
#  'Volusia',
#  'Volusia',
#  'Broward',
#  'A quarter mile north of Fort Pierce Inlet',
#  'Onslow',
#  'Monroe',
#  'Dade',
#  'Horry',
#  'Dare',
#  'Dare',
#  'Duval Country',
#  'Princess Anne',
#  'Manatee',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Horry',
#  'Horry',
#  'Monroe',
#  'Monroe',
#  'Chatham Island',
#  'Escambia',
#  'Nassau',
#  'Gulf Islands National Seashore',
#  'Charleston',
#  'Padre Island National Seashore',
#  'Catalina Island',
#  'Charleston',
#  'Galveston Island',
#  'Beaufort',
#  'Duval',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'St Lucie',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  "O'ahu",
#  'Volusia',
#  'Volusia',
#  'Oahu',
#  'Martin',
#  'San Diego',
#  'Lee',
#  'Flagler',
#  'Humboldt',
#  'St Lucie',
#  'Olowalu',
#  'Indian River',
#  'Palm Beach',
#  'Volusia',
#  'Volusia',
#  'New Hanover',
#  'San Mateo',
#  'Charleston',
#  'St Lucie',
#  'Indian River or Brevard',
#  'Volusia',
#  'Indian River',
#  'Volusia',
#  'Volusia',
#  'Pinellas',
#  'Prince William Sound',
#  'Carteret',
#  'Maui',
#  'Duval',
#  'St. Johns',
#  'Carteret',
#  'Florida Keys',
#  'Volusia',
#  'Monroe',
#  'New Hanover',
#  'Brunswick',
#  'Volusia',
#  'Volusia',
#  'Corpus Christi',
#  'Currituck',
#  'Volusia',
#  'Manatee',
#  'Volusia',
#  'Volusia',
#  'Volusia',
#  'Escambia',
#  'Corpus Christi',
#  'Baldwin',
#  'Baldwin',
#  'Volusia',
#  'Volusia',
#  'Palm Beach',
#  'Santa Rosa Sound Escambia County',
#  'Palm Beach',
#  'Brevard',
#  'Palm Beach',
#  'Anacapa & Santa Cruz Islands',
#  'Palm Beach',
#  'Palm Beach',
#  'North Kona',
#  ...]

# %%
import pandas as pd
import numpy as np
from  geopy.geocoders import Nominatim
import folium
from folium import plugins
geolocator = Nominatim()

country ="US"

coordinate=[]
for i in:
    loc = geolocator.geocode(i+','+ country)
    coordinate.append(i)
    coordinate.append(float(loc.latitude))
    coordinate.append(float(loc.longitude))
    print("latitude is :" ,type(loc.latitude),"\nlongtitude is:" ,type(float(loc.longitude)))

df = pd.DataFrame(np.array(coordinate).reshape(-1,3))
df.columns=["city","latitude","longitude"]

# %%
import folium
import os

'''创建Map对象'''
m = folium.Map([41.8781, -87.6298], zoom_start=11)

'''查看m的类型'''
m.__class__
# Out:
# folium.folium.Map

# %%
# mark each city as a point
for index, row in df.iterrows():
    folium.CircleMarker(location=[float(row['latitude']), float(row['longitude'])],
                        radius=3,
                        popup=row['city'],
                        fill_color='#ffe6e6', # divvy color
                       ).add_to(m)

# %%
# plot heatmap
m.add_children(plugins.HeatMap([[float(row["latitude"]),float(row["longitude"])]for name, row in df.iterrows()]))
m

# %%
import subprocess
import webbrowser
from http.server import BaseHTTPRequestHandler, HTTPServer


PORT = 7000
HOST = '127.0.0.1'
SERVER_ADDRESS = '{host}:{port}'.format(host=HOST, port=PORT)
FULL_SERVER_ADDRESS = 'http://' + SERVER_ADDRESS


def TemproraryHttpServer(page_content_type, raw_data):
    """
    A simpe, temprorary http web server on the pure Python 3.
    It has features for processing pages with a XML or HTML content.
    """

    class HTTPServerRequestHandler(BaseHTTPRequestHandler):
        """
        An handler of request for the server, hosting XML-pages.
        """

        def do_GET(self):
            """Handle GET requests"""

            # response from page
            self.send_response(200)

            # set up headers for pages
            content_type = 'text/{0}'.format(page_content_type)
            self.send_header('Content-type', content_type)
            self.end_headers()

            # writing data on a page
            self.wfile.write(bytes(raw_data, encoding='utf'))

            return

    if page_content_type not in ['html', 'xml']:
        raise ValueError('This server can serve only HTML or XML pages.')

    page_content_type = page_content_type

    # kill a process, hosted on a localhost:PORT
    subprocess.call(['fuser', '-k', '{0}/tcp'.format(PORT)])

    # Started creating a temprorary http server.
    httpd = HTTPServer((HOST, PORT), HTTPServerRequestHandler)

    # run a temprorary http server
    httpd.serve_forever()


def run_html_server(html_data=None):

    if html_data is None:
        html_data = """
        <!DOCTYPE html>
        <html>
        <head>
        <title>Page Title</title>
        </head>
        <body>
        <h1>This is a Heading</h1>
        <p>This is a paragraph.</p>
        </body>
        </html>
        """

    # open in a browser URL and see a result
    webbrowser.open(FULL_SERVER_ADDRESS)

    # run server
    TemproraryHttpServer('html', html_data)

# ------------------------------------------------------------------------------------------------


# now let's save the visualization into the temp file and render it
from tempfile import NamedTemporaryFile
tmp = NamedTemporaryFile()
m.save(tmp.name)
with open(tmp.name) as f:
    folium_map_html = f.read()

run_html_server(folium_map_html)
